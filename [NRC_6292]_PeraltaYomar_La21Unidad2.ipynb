# %% [markdown]
# <a href="https://colab.research.google.com/github/YomarPeralta/Laboratorio2_LimpiezaDeDatos/blob/main/%5BNRC_6292%5D_PeraltaYomar_La21Unidad2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LABORATORIO LIMPIEZA DE DATOS**

# %%
''' Importacion de la libreria necesaria para poder cargar un dataset '''
import pandas as pd

# %%
''' Definicion de la variable en la cual se guardara mi dataset'''
df= pd.read_csv('data_act_01.csv')

# %%
''' Impresion y visualizacion del dataset'''
df
# Out:
#       CrimeId;OriginalCrimeTypeName;OffenseDate;CallTime;CallDateTime;Disposition;Address;City;State;AgencyId;Range;AddressType
# 0      160903280;Assault / Battery;2016-03-30T00:00:0...
# 1      160912272;Homeless Complaint;2016-03-31T00:00:...
# 2      160912590;Susp Info;2016-03-31T00:00:00;16:49;...
# 3      160912801;Report;2016-03-31T00:00:00;17:38;201...
# 4      160912811;594;2016-03-31T00:00:00;17:42;2016-0...
# ...                                                  ...
# 10046  160964210;Well Being Check;2016-04-05T00:00:00...
# 10047  160964216;Traffic Stop;2016-04-05T00:00:00;23:...
# 10048  160964227;Traffic Stop;2016-04-05T00:00:00;23:...
# 10049  160964229;Passing Call;2016-04-05T00:00:00;23:...
# 10050  160964249;Traffic Stop;2016-04-05T00:00:00;23:...
#
# [10051 rows x 1 columns]

# %% [markdown]
# **ERROR 1 ! - Indentacion incorrecta del dataset**

# %%
'''Correccion del error numero 1 tratandose de la separacion de los diferentes registros de los campos de todo el dataset'''
df= pd.read_csv('data_act_01.csv', ';')
df
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          CrimeId OriginalCrimeTypeName          OffenseDate CallTime  \
# 0      160903280     Assault / Battery  2016-03-30T00:00:00    18:42
# 1      160912272    Homeless Complaint  2016-03-31T00:00:00    15:31
# 2      160912590             Susp Info  2016-03-31T00:00:00    16:49
# 3      160912801                Report  2016-03-31T00:00:00    17:38
# 4      160912811                   594  2016-03-31T00:00:00    17:42
# ...          ...                   ...                  ...      ...
# 10046  160964210      Well Being Check  2016-04-05T00:00:00    23:38
# 10047  160964216          Traffic Stop  2016-04-05T00:00:00    23:43
# 10048  160964227          Traffic Stop  2016-04-05T00:00:00    23:48
# ...

# %% [markdown]
# **ERROR** **2** ! - **Datos** **extensos**

# %%
'''Analisis de los datos del campo AddressType incluyendo registros nulos si los tuviera'''
print(df['AddressType'].value_counts(dropna=False))
# Out:
# Premise Address    5059
# Intersection       3701
# Common Location     818
# Geo-Override        469
# 1                     3
# Intersectioon         1
# Name: AddressType, dtype: int64

# %%
'''Cambio de datos por string por datos simples del campo AddressType para ahorro de memoria '''
d1 = {'Premise Address': 0, 'Intersection': 1, 'Common Location': 2, 'Geo-Override': 3, '1': 4, 'Intersectioon': 5}
df['AddressType'] = df['AddressType'].map(d1)

# %%
df
# Out:
#          CrimeId OriginalCrimeTypeName          OffenseDate CallTime  \
# 0      160903280     Assault / Battery  2016-03-30T00:00:00    18:42
# 1      160912272    Homeless Complaint  2016-03-31T00:00:00    15:31
# 2      160912590             Susp Info  2016-03-31T00:00:00    16:49
# 3      160912801                Report  2016-03-31T00:00:00    17:38
# 4      160912811                   594  2016-03-31T00:00:00    17:42
# ...          ...                   ...                  ...      ...
# 10046  160964210      Well Being Check  2016-04-05T00:00:00    23:38
# 10047  160964216          Traffic Stop  2016-04-05T00:00:00    23:43
# 10048  160964227          Traffic Stop  2016-04-05T00:00:00    23:48
# 10049  160964229          Passing Call  2016-04-05T00:00:00    23:48
# 10050  160964249          Traffic Stop  2016-04-05T00:00:00    23:54
#
#               CallDateTime   Disposition                  Address  \
# 0      2016-03-30T18:42:00           REP  100 Block Of Chilton Av
# ...

# %%
'''Visualizacion general del dataset con los cambios ya realizados'''
df.head()
# Out:
#      CrimeId OriginalCrimeTypeName          OffenseDate CallTime  \
# 0  160903280     Assault / Battery  2016-03-30T00:00:00    18:42
# 1  160912272    Homeless Complaint  2016-03-31T00:00:00    15:31
# 2  160912590             Susp Info  2016-03-31T00:00:00    16:49
# 3  160912801                Report  2016-03-31T00:00:00    17:38
# 4  160912811                   594  2016-03-31T00:00:00    17:42
#
#           CallDateTime Disposition                  Address           City  \
# 0  2016-03-30T18:42:00         REP  100 Block Of Chilton Av  San Francisco
# 1  2016-03-31T15:31:00         GOA  2300 Block Of Market St  San Francisco
# 2  2016-03-31T16:49:00         GOA  2300 Block Of Market St  San Francisco
# 3  2016-03-31T17:38:00         GOA      500 Block Of 7th St  San Francisco
# 4  2016-03-31T17:42:00         REP       Beale St/bryant St  San Francisco
#
#   State AgencyId  Range  AddressType
# 0    CA        1    NaN            0
# 1    CA        1    NaN            0
# ...

# %%
'''Detalle de los registros nulos que exitan en cada uno de los campos 
despues de los cambios que se realicen, que en este caso son City, State y Range'''
df.isnull().sum()
# Out:
# CrimeId                      0
# OriginalCrimeTypeName        0
# OffenseDate                  0
# CallTime                     0
# CallDateTime                 0
# Disposition                  0
# Address                      0
# City                       321
# State                        3
# AgencyId                     0
# Range                    10051
# AddressType                  0
# dtype: int64

# %% [markdown]
# **ERROR 3 ! - Datos faltantes en el campo City**

# %%
import numpy as np

# %%
''' Como se puede visualizar en el campo de City hacen falta registros, 
entonces para dicho error lo corregimos con su eliminacion''' 
df.isnull().sum()
# Out:
# CrimeId                      0
# OriginalCrimeTypeName        0
# OffenseDate                  0
# CallTime                     0
# CallDateTime                 0
# Disposition                  0
# Address                      0
# City                       321
# State                        3
# AgencyId                     0
# Range                    10051
# AddressType                  0
# dtype: int64

# %%
''' Analisis del campo en el cual existen 321 registros faltantes (Nan)'''
print(df['City'].value_counts(dropna=False))
# Out:
# San Francisco    9665
# NaN               321
# Treasure Isla      51
# Daly City           5
# Yerba Buena         3
# Presidio            3
# SAN FRANCISCO       1
#  S                  1
# Brisbane            1
# Name: City, dtype: int64

# %%
''' Impresion de los registros de la columna City y Address 
para la verificacion de los datos nulos que ubicacion tienen '''
df.loc[:, ['City', 'Address']]
# Out:
#                 City                  Address
# 0      San Francisco  100 Block Of Chilton Av
# 1      San Francisco  2300 Block Of Market St
# 2      San Francisco  2300 Block Of Market St
# 3      San Francisco      500 Block Of 7th St
# 4      San Francisco       Beale St/bryant St
# ...              ...                      ...
# 10046  San Francisco    Hollister Av/hawes St
# 10047  San Francisco   California St/mason St
# 10048  San Francisco   Rosella Ct/onondaga Av
# 10049  San Francisco          0 Blk Herbst Rd
# 10050  San Francisco        Grant Av/geary St
#
# [10051 rows x 2 columns]

# %%
'''Cambio del registro tipo NaN en el campo City dandole valor de 0'''
df[['City']] = df[['City']].fillna(value=0)

# %%
print(df['City'].value_counts(dropna=False))
# Out:
# San Francisco    9665
# 0                 321
# Treasure Isla      51
# Daly City           5
# Yerba Buena         3
# Presidio            3
# SAN FRANCISCO       1
#  S                  1
# Brisbane            1
# Name: City, dtype: int64

# %%
df.groupby('City').count()
# Out:
#                CrimeId  OriginalCrimeTypeName  OffenseDate  CallTime  \
# City
# 0                  321                    321          321       321
#  S                   1                      1            1         1
# Brisbane             1                      1            1         1
# Daly City            5                      5            5         5
# Presidio             3                      3            3         3
# SAN FRANCISCO        1                      1            1         1
# San Francisco     9665                   9665         9665      9665
# Treasure Isla       51                     51           51        51
# Yerba Buena          3                      3            3         3
#
#                CallDateTime  Disposition  Address  State  AgencyId  Range  \
# City
# 0                       321          321      321    319       321      0
#  S                        1            1        1      0         1      0
# ...

# %%
'''Verificacion de la limpieza'''
df.isnull().sum()
# Out:
# CrimeId                      0
# OriginalCrimeTypeName        0
# OffenseDate                  0
# CallTime                     0
# CallDateTime                 0
# Disposition                  0
# Address                      0
# City                         0
# State                        3
# AgencyId                     0
# Range                    10051
# AddressType                  0
# dtype: int64

# %% [markdown]
# **ERROR 4 ! - Columna "Range" sin valores ni registros validos**

# %%
'''Eliminacion de la columna "Range" ya que en la misma no existen datos validos'''
df.drop(['Range'], axis='columns', inplace=True)

# %%
''' Impresion de los datos ya sin la columna Range'''
df
# Out:
#          CrimeId OriginalCrimeTypeName          OffenseDate CallTime  \
# 0      160903280     Assault / Battery  2016-03-30T00:00:00    18:42
# 1      160912272    Homeless Complaint  2016-03-31T00:00:00    15:31
# 2      160912590             Susp Info  2016-03-31T00:00:00    16:49
# 3      160912801                Report  2016-03-31T00:00:00    17:38
# 4      160912811                   594  2016-03-31T00:00:00    17:42
# ...          ...                   ...                  ...      ...
# 10046  160964210      Well Being Check  2016-04-05T00:00:00    23:38
# 10047  160964216          Traffic Stop  2016-04-05T00:00:00    23:43
# 10048  160964227          Traffic Stop  2016-04-05T00:00:00    23:48
# 10049  160964229          Passing Call  2016-04-05T00:00:00    23:48
# 10050  160964249          Traffic Stop  2016-04-05T00:00:00    23:54
#
#               CallDateTime   Disposition                  Address  \
# 0      2016-03-30T18:42:00           REP  100 Block Of Chilton Av
# ...

# %%
'''Verificacion de la limpieza'''
df.isnull().sum()
# Out:
# CrimeId                  0
# OriginalCrimeTypeName    0
# OffenseDate              0
# CallTime                 0
# CallDateTime             0
# Disposition              0
# Address                  0
# City                     0
# State                    3
# AgencyId                 0
# AddressType              0
# dtype: int64

# %% [markdown]
# **ERROR 5 ! Redundancia de mayusculas y minusculas**

# %%
'''En el campo de Ciudad  existen registros tipo SAN FRANCISCO, S y San Francisco'''
df['City']= df['City'].replace('San Francisco','SAN FRANCISCO')

# %%
'''Cambio del registro tipo "S" a "SAN FRANCISCO"'''
df['City']= df['City'].replace(' S', 'SAN FRANCISCO')

# %%
df['City']= df['City'].replace(0, 'SAN FRANCISCO')

# %%
df.groupby('City').count()
# Out:
#                CrimeId  OriginalCrimeTypeName  OffenseDate  CallTime  \
# City
# Brisbane             1                      1            1         1
# Daly City            5                      5            5         5
# Presidio             3                      3            3         3
# SAN FRANCISCO     9988                   9988         9988      9988
# Treasure Isla       51                     51           51        51
# Yerba Buena          3                      3            3         3
#
#                CallDateTime  Disposition  Address  State  AgencyId  \
# City
# Brisbane                  1            1        1      1         1
# Daly City                 5            5        5      5         5
# Presidio                  3            3        3      3         3
# SAN FRANCISCO          9988         9988     9988   9985      9988
# Treasure Isla            51           51       51     51        51
# ...

# %%
'''Sumatoria de los registros faltantes en el dataset'''
df.isnull().sum()
# Out:
# CrimeId                  0
# OriginalCrimeTypeName    0
# OffenseDate              0
# CallTime                 0
# CallDateTime             0
# Disposition              0
# Address                  0
# City                     0
# State                    3
# AgencyId                 0
# AddressType              0
# dtype: int64

# %% [markdown]
# **ERROR 6 ! Valores nulos en el campo State**

# %%
''' El campo "AgencyId" posee 3 registros invalidos '''
df[['State']] = df[['State']].fillna(value=0)

# %%
df
# Out:
#          CrimeId OriginalCrimeTypeName          OffenseDate CallTime  \
# 0      160903280     Assault / Battery  2016-03-30T00:00:00    18:42
# 1      160912272    Homeless Complaint  2016-03-31T00:00:00    15:31
# 2      160912590             Susp Info  2016-03-31T00:00:00    16:49
# 3      160912801                Report  2016-03-31T00:00:00    17:38
# 4      160912811                   594  2016-03-31T00:00:00    17:42
# ...          ...                   ...                  ...      ...
# 10046  160964210      Well Being Check  2016-04-05T00:00:00    23:38
# 10047  160964216          Traffic Stop  2016-04-05T00:00:00    23:43
# 10048  160964227          Traffic Stop  2016-04-05T00:00:00    23:48
# 10049  160964229          Passing Call  2016-04-05T00:00:00    23:48
# 10050  160964249          Traffic Stop  2016-04-05T00:00:00    23:54
#
#               CallDateTime   Disposition                  Address  \
# 0      2016-03-30T18:42:00           REP  100 Block Of Chilton Av
# ...

# %%
print(df['State'].value_counts(dropna=False))
# Out:
# CA    10048
# 0         3
# Name: State, dtype: int64

# %%
df.groupby('State').count()
# Out:
#        CrimeId  OriginalCrimeTypeName  OffenseDate  CallTime  CallDateTime  \
# State
# 0            3                      3            3         3             3
# CA       10048                  10048        10048     10048         10048
#
#        Disposition  Address   City  AgencyId  AddressType
# State
# 0                3        3      3         3            3
# CA           10048    10048  10048     10048        10048

# %%
df['State']= df['State'].replace('CA', '1')

# %%
df.groupby('State').count()
# Out:
#        CrimeId  OriginalCrimeTypeName  OffenseDate  CallTime  CallDateTime  \
# State
# 0            3                      3            3         3             3
# 1        10048                  10048        10048     10048         10048
#
#        Disposition  Address   City  AgencyId  AddressType
# State
# 0                3        3      3         3            3
# 1            10048    10048  10048     10048        10048

# %%
'''Verficiacion de la limpieza de los registros nulos en el dataset'''
df.isnull().sum()
# Out:
# CrimeId                  0
# OriginalCrimeTypeName    0
# OffenseDate              0
# CallTime                 0
# CallDateTime             0
# Disposition              0
# Address                  0
# City                     0
# State                    0
# AgencyId                 0
# AddressType              0
# dtype: int64

# %% [markdown]
# **ERROR ! - Tipo de registro de una columna ya limpada**

# %%
'''Cambio del campo State de tipo object a tipo int'''
df['State']=pd.to_numeric(df['State'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10051 entries, 0 to 10050
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CrimeId                10051 non-null  int64
#  1   OriginalCrimeTypeName  10051 non-null  object
#  2   OffenseDate            10051 non-null  object
#  3   CallTime               10051 non-null  object
#  4   CallDateTime           10051 non-null  object
#  5   Disposition            10051 non-null  object
#  6   Address                10051 non-null  object
#  7   City                   10051 non-null  object
#  8   State                  10051 non-null  int64
#  9   AgencyId               10051 non-null  object
#  10  AddressType            10051 non-null  int64
# dtypes: int64(3), object(8)
# memory usage: 863.9+ KB

# %% [markdown]
# **ERROR  ! - Dato numerico incorrecto en campo  Disposition**

# %%
'''Visualizacion de los tipos de registros que existen en el campo Disposition'''
print(df['Disposition'].value_counts(dropna=False))
# Out:
# HAN             2820
# CIT             1425
# GOA             1273
# ADV             1142
# REP              800
# Not recorded     543
# ND               427
# UTL              385
# CAN              353
# NOM              324
# PAS              170
# ABA               97
# NCR               82
# 22                77
# ARR               65
# ADM               48
# INC               17
# CRT                2
# SFD                1
# Name: Disposition, dtype: int64

# %% [markdown]
# **ERROR ! - Registro numerico en campo no correspondiente**

# %%
'''Cambio del registro "Not Recorded" a NR'''
df['Disposition']= df['Disposition'].replace('Not recorded', 'NR')

# %%
'''Cambio del registro "22" a ABC'''
df['Disposition']= df['Disposition'].replace('22', 'ABC')

# %%
print(df['Disposition'].value_counts(dropna=False))
# Out:
# HAN    2820
# CIT    1425
# GOA    1273
# ADV    1142
# REP     800
# NR      543
# ND      427
# UTL     385
# CAN     353
# NOM     324
# PAS     170
# ABA      97
# NCR      82
# ABC      77
# ARR      65
# ADM      48
# INC      17
# CRT       2
# SFD       1
# Name: Disposition, dtype: int64

# %% [markdown]
# **ERROR ! - Formato de las fechas y horas del CallDateTime**

# %%
'''Con la ayuda del comando datetime se pudo cambiar el formato de la horay fecha del registro'''
df['CallDateTime'] = pd.to_datetime(df['CallDateTime'])
df
# Out:
#          CrimeId OriginalCrimeTypeName          OffenseDate CallTime  \
# 0      160903280     Assault / Battery  2016-03-30T00:00:00    18:42
# 1      160912272    Homeless Complaint  2016-03-31T00:00:00    15:31
# 2      160912590             Susp Info  2016-03-31T00:00:00    16:49
# 3      160912801                Report  2016-03-31T00:00:00    17:38
# 4      160912811                   594  2016-03-31T00:00:00    17:42
# ...          ...                   ...                  ...      ...
# 10046  160964210      Well Being Check  2016-04-05T00:00:00    23:38
# 10047  160964216          Traffic Stop  2016-04-05T00:00:00    23:43
# 10048  160964227          Traffic Stop  2016-04-05T00:00:00    23:48
# 10049  160964229          Passing Call  2016-04-05T00:00:00    23:48
# 10050  160964249          Traffic Stop  2016-04-05T00:00:00    23:54
#
#              CallDateTime Disposition                  Address           City  \
# ...

# %% [markdown]
# **ERROR ! - Formato de la fecha inconsistente**

# %%
'''Cambio del formato de la hora en el campo OffenseDate'''
df['OffenseDate'] = pd.to_datetime(df['OffenseDate'])
df
# Out:
#          CrimeId OriginalCrimeTypeName OffenseDate CallTime  \
# 0      160903280     Assault / Battery  2016-03-30    18:42
# 1      160912272    Homeless Complaint  2016-03-31    15:31
# 2      160912590             Susp Info  2016-03-31    16:49
# 3      160912801                Report  2016-03-31    17:38
# 4      160912811                   594  2016-03-31    17:42
# ...          ...                   ...         ...      ...
# 10046  160964210      Well Being Check  2016-04-05    23:38
# 10047  160964216          Traffic Stop  2016-04-05    23:43
# 10048  160964227          Traffic Stop  2016-04-05    23:48
# 10049  160964229          Passing Call  2016-04-05    23:48
# 10050  160964249          Traffic Stop  2016-04-05    23:54
#
#              CallDateTime Disposition                  Address           City  \
# 0     2016-03-30 18:42:00         REP  100 Block Of Chilton Av  SAN FRANCISCO
# 1     2016-03-31 15:31:00         GOA  2300 Block Of Market St  SAN FRANCISCO
# ...

# %%
''' Metodo para poder hacer el nuevo reporte del dataset ya trabajado limpido en formato Json'''
df.to_json('data_act_01_DatosLimpios.json', orient='records', lines=True)
